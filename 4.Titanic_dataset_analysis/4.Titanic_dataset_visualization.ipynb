# %% [markdown]
# DATASET OVERVIEW
#
# Titanic Dataset
#
# Total Entries: 891 rows, 12 columns
#
# Purpose: This dataset is used to train models to predict survival outcomes on the Titanic.
#
# Key Columns:
#
# PassengerId: Unique identifier for each passenger.
#
# Survived: Survival status (0 = No, 1 = Yes).
#
# Pclass: Ticket class (1 = First, 2 = Second, 3 = Third).
#
# Name: Full name of the passenger.
#
# Sex: Gender of the passenger.
#
# Age: Age of the passenger (some missing values).
#
# SibSp: Number of siblings/spouses aboard.
#
# Parch: Number of parents/children aboard.
#
# Ticket: Ticket number.
#
# Fare: Ticket fare.
#
# Cabin: Cabin number (many missing values).
#
# Embarked: Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
tt=pd.read_csv('Titanic-Dataset.csv')

# %%
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.countplot(x="Survived",hue="Pclass",data=tt)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Sex",data=tt)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Pclass",hue="Sex",data=tt)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="Survived",data=tt)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(6, 6))
sns.countplot(data=tt, x='Survived', palette='viridis')
plt.xlabel("Survived", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.title("Exploratory Data Analysis: Survival Count", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(6, 6))
tt['Survived'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', labels=['Not Survived', 'Survived'], colors=['lightcoral', 'lightgreen']
)
plt.title('Survival Distribution')
plt.ylabel('')
plt.show()

# %%
pclass_counts = tt['Pclass'].value_counts()
plt.pie(pclass_counts, labels=['Class 1', 'Class 2', 'Class 3'], autopct='%1.1f%%', startangle=90)
plt.title("Passenger Class Distribution")
plt.show()

# %%
sibsp_counts = tt['SibSp'].value_counts()
plt.pie(sibsp_counts, labels=sibsp_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("SibSp Distribution")
plt.show()

# %%
parch_counts = tt['Parch'].value_counts()
colors = ['lightblue', 'lightgreen', 'gold', 'salmon', 'violet', 'orange', 'pink'] 
plt.pie(parch_counts, labels=parch_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title("Parch Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 6))
tt['Sex'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', labels=['Male', 'Female'], colors=['skyblue', 'pink']
)
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
# Pie chart for 'Embarked' with custom colors
embarked_counts = tt['Embarked'].value_counts()
colors = ['lightblue', 'lightgreen', 'gold', 'salmon']  # Custom colors
plt.pie(embarked_counts, labels=embarked_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title("Embarked Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=tt, x='Pclass', palette='viridis')
plt.xlabel("Pclass", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=tt, x='Pclass', palette='viridis')
plt.xlabel("Pclass", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=tt, x='Sex', palette='viridis')
plt.xlabel("Sex", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=tt, x='SibSp', palette='viridis')
plt.xlabel("SibSp'", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=tt, x='Parch', palette='viridis')
plt.xlabel("Parch'", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=tt, x='Embarked', palette='viridis')
plt.xlabel("SibSp'", fontsize=12)  
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
sns.barplot(data=tt, x='Survived', y='Fare', hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.countplot(tt['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(tt['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
sns.countplot(tt['SibSp'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(tt['Parch'])
# Out:
# <Axes: ylabel='count'>

# %%
#EDA
sns.countplot(tt['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
#EDA
sns.distplot(tt['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(tt['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
class_fare= tt.pivot_table(index="Pclass",values="Fare")
class_fare.plot(kind='bar')
plt.xlabel('Pclass')
plt.ylabel('Avg.Fare')
plt.xticks(rotation=0)
plt.show()

# %%
class_fare= tt.pivot_table(index="Pclass",values="Fare",aggfunc=np.sum)
class_fare.plot(kind='bar')
plt.xlabel('Pclass')
plt.ylabel('Total Fare')
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(data=tt,x='Pclass',y='Fare',hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
#DP
tt_len=len(tt)
df=pd.concat([tt],axis=0)
df.reset_index(drop=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Fare']=df['Fare'].fillna(df['Fare'].mean())

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
sns.distplot(tt['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
df['Fare']=np.log(df['Fare']+1)

# %%
sns.distplot(df['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Sex', 'Embarked']
le = LabelEncoder()

for col in cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket      Fare  Embarked
# 0         A/5 21171  2.110213         2
# 1          PC 17599  4.280593         0
# 2  STON/O2. 3101282  2.188856         2
# 3            113803  3.990834         2
# 4            373450  2.202765         2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure df only includes numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
corr = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 9))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # OVERALL OBSERVATION

# %% [markdown]
# Survival Prediction: Using Pclass, Sex, Age, and Fare to predict survival.
#
# Passenger Profiling: Analyzing different passenger demographics based on class, gender, and embarkation points.
#
# Data Cleaning & Feature Engineering: Handling missing values in Age and Cabin before analysis.

# %% [markdown]
# Survival Distribution:
#
# The analysis likely includes visualizations showing the proportion of survivors (1) and non-survivors (0).
# A significant number of passengers did not survive, as seen from previous Titanic dataset studies.
# Gender & Survival:
#
# Women had a higher survival rate than men, indicating the "women and children first" policy during evacuation.
# Passenger Class Impact:
#
# First-class passengers had a higher survival rate compared to second and third-class passengers.
# Age Influence:
#
# Younger passengers (children) had a higher chance of survival.
# Embarkation Port & Survival:
#
# The embarkation point may have had an impact on survival rates.
# Fare & Survival:
#
# Higher fares were associated with better survival chances, likely because wealthier passengers were in first-class accommodations.
#
# Gender, Passenger Class, and Fare played crucial roles in survival.
